# %%
import sys
from pathlib import Path
import os
import pickle
import random
import shutil

import glob2 as glob
import tensorflow as tf
from azureml.core import Experiment, Workspace
from azureml.core.run import Run
from tensorflow.keras import callbacks

sys.path.append(str(Path(os.getcwd()) / 'src'))

from config import CONFIG
from constants import REPO_DIR
from model import create_cnn

sys.path.append(str(REPO_DIR / 'src/common'))

from model_utils.preprocessing import preprocess_depthmap, preprocess_targets
from model_utils.lr_finder import LRFinder

# %%
# Make experiment reproducible
tf.random.set_seed(CONFIG.SPLIT_SEED)
random.seed(CONFIG.SPLIT_SEED)

# Get the current run.
run = Run.get_context()

# Offline run. Download the sample dataset and run locally. Still push results to Azure.
if(run.id.startswith("OfflineRun")):
    print("Running in offline mode...")

    # Access workspace.
    print("Accessing workspace...")
    workspace = Workspace.from_config()
    experiment = Experiment(workspace, "training-junkyard")
    run = experiment.start_logging(outputs=None, snapshot_directory=None)

    # Get dataset.
    print("Accessing dataset...")
    dataset_name = "anon-depthmap-mini"
    dataset_path = str(REPO_DIR / "data" / dataset_name)
    if not os.path.exists(dataset_path):
        dataset = workspace.datasets[dataset_name]
        dataset.download(target_path=dataset_path, overwrite=False)

# Online run. Use dataset provided by training notebook.
else:
    print("Running in online mode...")
    experiment = run.experiment
    workspace = experiment.workspace
    dataset_path = run.input_datasets["dataset"]
# Out:
# Running in offline mode...
# Accessing workspace...
# Accessing dataset...

# %%
# Get the QR-code paths.
dataset_path = os.path.join(dataset_path, "scans")
print("Dataset path:", dataset_path)
#print(glob.glob(os.path.join(dataset_path, "*"))) # Debug
print("Getting QR-code paths...")
qrcode_paths = glob.glob(os.path.join(dataset_path, "*"))
print("qrcode_paths: ", len(qrcode_paths))
assert len(qrcode_paths) != 0

# Shuffle and split into train and validate.
random.shuffle(qrcode_paths)
split_index = int(len(qrcode_paths) * 0.8)
qrcode_paths_training = qrcode_paths[:split_index]
qrcode_paths_validate = qrcode_paths[split_index:]
qrcode_paths_activation = random.choice(qrcode_paths_validate)
qrcode_paths_activation = [qrcode_paths_activation]

del qrcode_paths

# Show split.
print("Paths for training:")
print("\t" + "\n\t".join(qrcode_paths_training))
print("Paths for validation:")
print("\t" + "\n\t".join(qrcode_paths_validate))
print("Paths for activation:")
print("\t" + "\n\t".join(qrcode_paths_activation))

print(len(qrcode_paths_training))
print(len(qrcode_paths_validate))

assert len(qrcode_paths_training) > 0 and len(qrcode_paths_validate) > 0


def get_depthmap_files(paths):
    pickle_paths = []
    for path in paths:
        pickle_paths.extend(glob.glob(os.path.join(path, "**", "*.p")))
    return pickle_paths


# Get the pointclouds.
print("Getting depthmap paths...")
paths_training = get_depthmap_files(qrcode_paths_training)
paths_validate = get_depthmap_files(qrcode_paths_validate)
paths_activate = get_depthmap_files(qrcode_paths_activation)

del qrcode_paths_training
del qrcode_paths_validate
del qrcode_paths_activation

print("Using {} files for training.".format(len(paths_training)))
print("Using {} files for validation.".format(len(paths_validate)))
print("Using {} files for validation.".format(len(paths_activate)))


# Function for loading and processing depthmaps.
def tf_load_pickle(path, max_value):
    def py_load_pickle(path, max_value):
        depthmap, targets = pickle.load(open(path.numpy(), "rb"))
        depthmap = preprocess_depthmap(depthmap)
        depthmap = depthmap / max_value
        depthmap = tf.image.resize(depthmap, (CONFIG.IMAGE_TARGET_HEIGHT, CONFIG.IMAGE_TARGET_WIDTH))
        targets = preprocess_targets(targets, CONFIG.TARGET_INDEXES)
        return depthmap, targets

    depthmap, targets = tf.py_function(py_load_pickle, [path, max_value], [tf.float32, tf.float32])
    depthmap.set_shape((CONFIG.IMAGE_TARGET_HEIGHT, CONFIG.IMAGE_TARGET_WIDTH, 1))
    targets.set_shape((len(CONFIG.TARGET_INDEXES,)))
    return depthmap, targets


def tf_flip(image):
    image = tf.image.random_flip_left_right(image)
    return image
# Out:
# Dataset path: /Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans
# Getting QR-code paths...
# qrcode_paths:  200
# Paths for training:
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585000019-syglokl9nx
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585359302-xgr04tzu1x
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585004555-pdy6rqar2k
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583465004-e08aft4qoi
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585015338-j5bywnvx0m
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585004959-pa1bzmqc2z
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583464407-99ik4m3cuf
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585119077-65v2b8mgz4
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585296863-bs7f3iy4ah
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585296836-xdg7yby3dn
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585352959-6299gr8lr2
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585014231-2v1ubh6pf9
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585006907-kv8l5uu9sc
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583779266-ci3y8yxjkr
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585004224-ollmnqhwpc
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585002272-brifnhigac
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585361910-69awqv24hn
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583831593-vet4fbovf2
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585273497-t9fr8pxdbv
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585002256-81x2tyf100
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585350357-8hhag1ws9i
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585364660-i79nhw4m35
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585297401-uhjfc2n38p
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585014415-106dmwetel
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585466217-g3efktatik
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585000958-alh2nvawq8
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585009524-43kj4i97wi
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585297607-1bd4lw51hn
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585363227-a0lpvx8d7z
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585002524-pxe64yjoci
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585005340-85jdi2l3cn
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585014809-3c76aqc9as
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584924080-hrsht1ikhl
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585365555-u78qt9sj10
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585009440-ehc0r47knp
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583515002-2zoh82mgvp
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584995406-7lg1eukxk9
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585001866-jvyz3b919o
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584998588-il0q52hb6q
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585268885-6fvkb2kecs
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584993741-g6q1a5ktab
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585004920-4beg3r2hsd
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585119462-3n4tsxbmy5
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585353338-boa4phzps5
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583758824-vv0iquusso
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583509396-yquxv3fdnx
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585008507-wul139kty5
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584997945-2ab13amb91
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583462470-16tvfmb1d0
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584999980-0eyydh10ah
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585359869-62y7zlvz9z
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585007761-cyt8w90xrg
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585297385-0r7oshmk9z
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583462505-43bak4gvfa
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585010378-49y153ng7s
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584997821-edlbyd8arl
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585011205-lfwpt1wumu
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585357967-c356zwbqg9
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585005079-dxf2e5o1vv
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585000649-hpvb83uhy3
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585384173-ugh191r433
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584997615-7x228v9pbw
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583942091-02migjdla1
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585008219-pmodlmuq4c
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585002508-jxhr7ves3z
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584995166-5txlihdhni
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585363431-xl6picilis
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585461590-32qk6jndim
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585000248-k4adlb4r9h
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585271792-wr7pbck6lp
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585012847-l697gvmg0n
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585014321-lpimmih832
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583926813-qrsv28lhhh
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585271358-mo2bxdlw6z
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585007035-fpqempvvpe
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585004510-nhjz3c1tvr
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585273973-8vy7jncv83
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584930386-n4xepqqqze
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584993482-iku7o0kdmu
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585358041-oz79ac6mus
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585005576-5wegazlcs6
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584752995-m2uiox05f6
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585001292-8diga5ujxe
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585004313-3nkq4je2sh
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585267901-cyvy3n5twy
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585296726-egy9zkb4mt
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583997761-a6g8fohu1l
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584994945-pyxhivwe2y
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585119184-p4l17j1d9p
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585361823-p8701v7cio
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583999126-cku6yskcp1
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1583854960-jw7fgnqv72
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584996550-uz8no9he38
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1584750813-nogv7bodvl
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585012878-6v6ywmesan
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585273988-1i6byv9a57
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585350651-lhwnjqqjbj
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585013129-135py583fc
# Paths for activation:
# 	/Users/markus/Development/cgm/cgm-ml/data/anon-depthmap-mini/scans/1585363861-lven8e892k
# 160
# 40
# Getting depthmap paths...
# Using 3288 files for training.
# Using 789 files for validation.
# Using 20 files for validation.

# %%
# Create dataset for training.
paths = paths_training
dataset = tf.data.Dataset.from_tensor_slices(paths)
dataset_norm = dataset.map(lambda path: tf_load_pickle(path, CONFIG.NORMALIZATION_VALUE))
dataset_norm = dataset_norm.cache()
dataset_norm = dataset_norm.prefetch(tf.data.experimental.AUTOTUNE)
dataset_norm = dataset_norm.shuffle(CONFIG.SHUFFLE_BUFFER_SIZE)
dataset_training = dataset_norm
del dataset_norm

# Create dataset for validation.
# Note: No shuffle necessary.
paths = paths_validate
dataset = tf.data.Dataset.from_tensor_slices(paths)
dataset_norm = dataset.map(lambda path: tf_load_pickle(path, CONFIG.NORMALIZATION_VALUE))
dataset_norm = dataset_norm.cache()
dataset_norm = dataset_norm.prefetch(tf.data.experimental.AUTOTUNE)
dataset_validation = dataset_norm
del dataset_norm

# Create dataset for activation
paths = paths_activate
dataset = tf.data.Dataset.from_tensor_slices(paths)
dataset_norm = dataset.map(lambda path: tf_load_pickle(path, CONFIG.NORMALIZATION_VALUE))
dataset_norm = dataset_norm.cache()
dataset_norm = dataset_norm.prefetch(tf.data.experimental.AUTOTUNE)
dataset_activation = dataset_norm
del dataset_norm

# Note: Now the datasets are prepared.

# Create the model.
input_shape = (CONFIG.IMAGE_TARGET_HEIGHT, CONFIG.IMAGE_TARGET_WIDTH, 1)
model = create_cnn(input_shape, dropout=True)

# %%
model.compile(optimizer='adam', loss="mse", metrics=["mae"])

# %% [markdown]
# # LR Find

# %%
lr_finder = LRFinder()
_ = model.fit(dataset_training.batch(CONFIG.BATCH_SIZE), epochs=5, callbacks=[lr_finder], verbose=2)
lr_finder.plot()
# Out:
# Epoch 1/5
# 13/13 - 256s - loss: 7920.1763 - mae: 88.4633
# Epoch 2/5
# 13/13 - 250s - loss: 7920.0938 - mae: 88.4628
# Epoch 3/5
# 13/13 - 252s - loss: 7916.7490 - mae: 88.4442
# Epoch 4/5
# 13/13 - 245s - loss: 8633.5850 - mae: 82.3054
# Epoch 5/5
# 13/13 - 245s - loss: 10850.2021 - mae: 94.6400

# %%
len(dataset_training)
